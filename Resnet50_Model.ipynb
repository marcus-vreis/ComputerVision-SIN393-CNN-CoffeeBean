# %% [markdown]
# ## Import Libraries

# %%
import torch
import torch.nn as nn
import zipfile
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Subset
import torchvision.models as models
from torchvision.models import AlexNet_Weights
import os
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, roc_curve, auc, precision_recall_curve
from sklearn.model_selection import train_test_split
import numpy as np
import tqdm

# %% [markdown]
# ## Using Seed for Replication

# %%
# Seed para replicar o modelo
SEED = 70
import random
random.seed(SEED)
np.random.seed(SEED)

torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)

torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

# %% [markdown]
# ## Using Transforms and Loading Datasets

# %%
transformacao = transforms.Compose([
    transforms.Resize((224, 224)),  # Entrada padrão para ResNet50
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])



# Carregar datasets
base_treinamento = datasets.ImageFolder(root='USK-Coffee/train', transform=transformacao)
train_dataloader = DataLoader(base_treinamento, batch_size=10, shuffle=True)

base_validacao = datasets.ImageFolder(root='USK-Coffee/val', transform=transformacao)
validation_dataloader = DataLoader(base_validacao, batch_size=10, shuffle=True)

base_teste = datasets.ImageFolder(root='USK-Coffee/test', transform=transformacao)
test_dataloader = DataLoader(base_teste, batch_size=1, shuffle=False)

# %%
'''

transformacao = transforms.Compose([
    transforms.Resize((190, 190)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]) 
])

# Carregar o dataset completo
base_dados = datasets.ImageFolder(root='Original', transform=transformacao)

# Dividir o dataset em treinamento e teste (30% para teste)
train_indices, test_indices = train_test_split(
    range(len(base_dados)), 
    test_size=0.3, 
    random_state=42, 
    stratify=base_dados.targets
)

base_treinamento = Subset(base_dados, train_indices)
base_teste = Subset(base_dados, test_indices)

# DataLoader para treinamento e teste
train_dataloader = DataLoader(base_treinamento, batch_size=10, shuffle=True)
test_dataloader = DataLoader(base_teste, batch_size=1, shuffle=False)

'''
# Out:
# "\n\ntransformacao = transforms.Compose([\n    transforms.Resize((190, 190)),\n    transforms.ToTensor(),\n    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]) \n])\n\n# Carregar o dataset completo\nbase_dados = datasets.ImageFolder(root='Original', transform=transformacao)\n\n# Dividir o dataset em treinamento e teste (30% para teste)\ntrain_indices, test_indices = train_test_split(\n    range(len(base_dados)), \n    test_size=0.3, \n    random_state=42, \n    stratify=base_dados.targets\n)\n\nbase_treinamento = Subset(base_dados, train_indices)\nbase_teste = Subset(base_dados, test_indices)\n\n# DataLoader para treinamento e teste\ntrain_dataloader = DataLoader(base_treinamento, batch_size=10, shuffle=True)\ntest_dataloader = DataLoader(base_teste, batch_size=1, shuffle=False)\n\n"

# %% [markdown]
# ## Creating Arquitecture

# %%
model = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1)

# Modificar a camada final para classificação binária
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 1)  # Saída com 1 unidade para classificação binária



# Definir dispositivo
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
print(device)
# Out:
# cuda

# %% [markdown]
# ## Def Acc, Train and Evaluate Functions

# %%
# Função de acurácia ajustada
def accuracy(outputs, labels):
    outputs = torch.sigmoid(outputs)  # Converte logits para probabilidades
    predicted = torch.round(outputs)
    correct = (predicted == labels).float()
    acc = correct.sum() / len(correct)
    return acc
    
# Definir loss function e otimizador
criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# Função de treinamento
def train(model, loader, optimizer, criterion):
    model.train()
    running_loss = 0.0
    running_accuracy = 0.0
    for inputs, labels in loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels.unsqueeze(1).float())
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
        running_accuracy += accuracy(outputs, labels.unsqueeze(1).float()).item() * inputs.size(0)
    epoch_loss = running_loss / len(loader.dataset)
    epoch_accuracy = running_accuracy / len(loader.dataset)
    return epoch_loss, epoch_accuracy

# Função de avaliação
def evaluate(model, loader, criterion):
    model.eval()
    running_loss = 0.0
    running_accuracy = 0.0
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels.unsqueeze(1).float())
            running_loss += loss.item() * inputs.size(0)
            running_accuracy += accuracy(outputs, labels.unsqueeze(1).float()).item() * inputs.size(0)
    epoch_loss = running_loss / len(loader.dataset)
    epoch_accuracy = running_accuracy / len(loader.dataset)
    return epoch_loss, epoch_accuracy

# %% [markdown]
# ## Def Checkpoint functions

# %%
class CustomModelCheckpoint:
    def __init__(self):
        self.best_val_accuracy = 0.0

    def __call__(self, epoch, val_accuracy, model, optimizer, loss):
        if val_accuracy > self.best_val_accuracy:
            print(f"Validation accuracy improved from {self.best_val_accuracy:.4f} to {val_accuracy:.4f}. Saving model...")
            self.best_val_accuracy = val_accuracy
            save_checkpoint(epoch, model, optimizer, loss)
            # Também salva o melhor modelo com um nome fixo
            save_best_model(model, optimizer, loss)

# Função para salvar checkpoint
def save_checkpoint(epoch, model, optimizer, loss):
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': loss,
    }
    torch.save(checkpoint, checkpoint_path.format(epoch=epoch))

# Função para salvar o melhor modelo
def save_best_model(model, optimizer, loss):
    checkpoint = {
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': loss,
    }
    torch.save(checkpoint, best_model_path)

# Configurações de checkpoint
checkpoint_dir = "modelos/pesos_Resnet50"
os.makedirs(checkpoint_dir, exist_ok=True)
checkpoint_path = os.path.join(checkpoint_dir, 'cp2-{epoch:04d}.pth')
best_model_path = os.path.join(checkpoint_dir, 'Melhor_modelo_Resnet50.pth')
cp_callback = CustomModelCheckpoint()

# %% [markdown]
# ## Training Model

# %%
# Listas para guardar os valores de acuracia e loss do modelo
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

epochs = 100  # mudar para a quantidade de épocas que desejar

for epoch in range(epochs):
    train_loss, train_accuracy = train(model, train_dataloader, optimizer, criterion)
    val_loss, val_accuracy = evaluate(model, validation_dataloader, criterion)

    # Adiciona loss e acurácia de treinamento e validação de cada época em uma lista
    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)
    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)

    print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
    cp_callback(epoch, val_accuracy, model, optimizer, val_loss)
# Out:
# Epoch 1/100, Train Loss: 0.2457, Train Acc: 0.8996, Val Loss: 0.2205, Val Acc: 0.9063
# Validation accuracy improved from 0.0000 to 0.9063. Saving model...
# Epoch 2/100, Train Loss: 0.1212, Train Acc: 0.9567, Val Loss: 0.2431, Val Acc: 0.8975
# Epoch 3/100, Train Loss: 0.0621, Train Acc: 0.9783, Val Loss: 0.1446, Val Acc: 0.9513
# Validation accuracy improved from 0.9063 to 0.9513. Saving model...
# Epoch 4/100, Train Loss: 0.0607, Train Acc: 0.9817, Val Loss: 0.2089, Val Acc: 0.9238
# Epoch 5/100, Train Loss: 0.0520, Train Acc: 0.9858, Val Loss: 0.1393, Val Acc: 0.9488
# Epoch 6/100, Train Loss: 0.0484, Train Acc: 0.9829, Val Loss: 0.1516, Val Acc: 0.9400
# Epoch 7/100, Train Loss: 0.0393, Train Acc: 0.9871, Val Loss: 0.1930, Val Acc: 0.9138
# Epoch 8/100, Train Loss: 0.0121, Train Acc: 0.9963, Val Loss: 0.0992, Val Acc: 0.9625
# Validation accuracy improved from 0.9513 to 0.9625. Saving model...
# Epoch 9/100, Train Loss: 0.0519, Train Acc: 0.9842, Val Loss: 0.2337, Val Acc: 0.9175
# Epoch 10/100, Train Loss: 0.0216, Train Acc: 0.9946, Val Loss: 0.1897, Val Acc: 0.9375
# Epoch 11/100, Train Loss: 0.0144, Train Acc: 0.9950, Val Loss: 0.1968, Val Acc: 0.9275
# Epoch 12/100, Train Loss: 0.0192, Train Acc: 0.9958, Val Loss: 0.1935, Val Acc: 0.9275
# Epoch 13/100, Train Loss: 0.0283, Train Acc: 0.9879, Val Loss: 0.3321, Val Acc: 0.8825
# Epoch 14/100, Train Loss: 0.0556, Train Acc: 0.9821, Val Loss: 0.1143, Val Acc: 0.9513
# Epoch 15/100, Train Loss: 0.0174, Train Acc: 0.9963, Val Loss: 0.1813, Val Acc: 0.9313
# Epoch 16/100, Train Loss: 0.0025, Train Acc: 0.9996, Val Loss: 0.1083, Val Acc: 0.9588
# Epoch 17/100, Train Loss: 0.0161, Train Acc: 0.9946, Val Loss: 0.0998, Val Acc: 0.9563
# Epoch 18/100, Train Loss: 0.0212, Train Acc: 0.9950, Val Loss: 0.1943, Val Acc: 0.9313
# Epoch 19/100, Train Loss: 0.0197, Train Acc: 0.9933, Val Loss: 0.1676, Val Acc: 0.9450
# Epoch 20/100, Train Loss: 0.0196, Train Acc: 0.9942, Val Loss: 0.2241, Val Acc: 0.9275
# Epoch 21/100, Train Loss: 0.0019, Train Acc: 0.9996, Val Loss: 0.0916, Val Acc: 0.9675
# Validation accuracy improved from 0.9625 to 0.9675. Saving model...
# Epoch 22/100, Train Loss: 0.0009, Train Acc: 1.0000, Val Loss: 0.1263, Val Acc: 0.9563
# Epoch 23/100, Train Loss: 0.0005, Train Acc: 1.0000, Val Loss: 0.1927, Val Acc: 0.9400
# Epoch 24/100, Train Loss: 0.0004, Train Acc: 1.0000, Val Loss: 0.1001, Val Acc: 0.9675
# Validation accuracy improved from 0.9675 to 0.9675. Saving model...
# Epoch 25/100, Train Loss: 0.0456, Train Acc: 0.9813, Val Loss: 2.0541, Val Acc: 0.6263
# Epoch 26/100, Train Loss: 0.0456, Train Acc: 0.9829, Val Loss: 0.4648, Val Acc: 0.8238
# Epoch 27/100, Train Loss: 0.0088, Train Acc: 0.9971, Val Loss: 0.1420, Val Acc: 0.9438
# Epoch 28/100, Train Loss: 0.0021, Train Acc: 0.9996, Val Loss: 0.2335, Val Acc: 0.9213
# Epoch 29/100, Train Loss: 0.0119, Train Acc: 0.9950, Val Loss: 0.1439, Val Acc: 0.9375
# Epoch 30/100, Train Loss: 0.0126, Train Acc: 0.9958, Val Loss: 0.1982, Val Acc: 0.9250
# Epoch 31/100, Train Loss: 0.0072, Train Acc: 0.9979, Val Loss: 0.1569, Val Acc: 0.9488
# Epoch 32/100, Train Loss: 0.0003, Train Acc: 1.0000, Val Loss: 0.2001, Val Acc: 0.9350
# Epoch 33/100, Train Loss: 0.0094, Train Acc: 0.9992, Val Loss: 0.8542, Val Acc: 0.7513
# Epoch 34/100, Train Loss: 0.0518, Train Acc: 0.9854, Val Loss: 0.1721, Val Acc: 0.9363
# Epoch 35/100, Train Loss: 0.0055, Train Acc: 0.9983, Val Loss: 0.0965, Val Acc: 0.9638
# Epoch 36/100, Train Loss: 0.0035, Train Acc: 0.9988, Val Loss: 0.1217, Val Acc: 0.9538
# Epoch 37/100, Train Loss: 0.0098, Train Acc: 0.9987, Val Loss: 0.1781, Val Acc: 0.9238
# Epoch 38/100, Train Loss: 0.0037, Train Acc: 0.9996, Val Loss: 0.2310, Val Acc: 0.9275
# Epoch 39/100, Train Loss: 0.0008, Train Acc: 0.9996, Val Loss: 0.2060, Val Acc: 0.9388
# Epoch 40/100, Train Loss: 0.0002, Train Acc: 1.0000, Val Loss: 0.1858, Val Acc: 0.9388
# Epoch 41/100, Train Loss: 0.0330, Train Acc: 0.9888, Val Loss: 0.4023, Val Acc: 0.8613
# Epoch 42/100, Train Loss: 0.0112, Train Acc: 0.9946, Val Loss: 0.0625, Val Acc: 0.9750
# Validation accuracy improved from 0.9675 to 0.9750. Saving model...
# Epoch 43/100, Train Loss: 0.0393, Train Acc: 0.9883, Val Loss: 0.1591, Val Acc: 0.9338
# Epoch 44/100, Train Loss: 0.0128, Train Acc: 0.9963, Val Loss: 0.5685, Val Acc: 0.8250
# Epoch 45/100, Train Loss: 0.0062, Train Acc: 0.9983, Val Loss: 0.0991, Val Acc: 0.9625
# Epoch 46/100, Train Loss: 0.0107, Train Acc: 0.9958, Val Loss: 0.1393, Val Acc: 0.9475
# Epoch 47/100, Train Loss: 0.0115, Train Acc: 0.9971, Val Loss: 0.1501, Val Acc: 0.9425
# Epoch 48/100, Train Loss: 0.0102, Train Acc: 0.9963, Val Loss: 0.1473, Val Acc: 0.9513
# Epoch 49/100, Train Loss: 0.0007, Train Acc: 1.0000, Val Loss: 0.3491, Val Acc: 0.9050
# Epoch 50/100, Train Loss: 0.0010, Train Acc: 1.0000, Val Loss: 0.2198, Val Acc: 0.9275
# Epoch 51/100, Train Loss: 0.0003, Train Acc: 1.0000, Val Loss: 0.1669, Val Acc: 0.9375
# Epoch 52/100, Train Loss: 0.0088, Train Acc: 0.9988, Val Loss: 0.1962, Val Acc: 0.9313
# Epoch 53/100, Train Loss: 0.0169, Train Acc: 0.9925, Val Loss: 0.3012, Val Acc: 0.9063
# Epoch 54/100, Train Loss: 0.0153, Train Acc: 0.9938, Val Loss: 0.2346, Val Acc: 0.9288
# Epoch 55/100, Train Loss: 0.0195, Train Acc: 0.9954, Val Loss: 0.1790, Val Acc: 0.9363
# Epoch 56/100, Train Loss: 0.0020, Train Acc: 0.9992, Val Loss: 0.2263, Val Acc: 0.9325
# Epoch 57/100, Train Loss: 0.0124, Train Acc: 0.9954, Val Loss: 0.1638, Val Acc: 0.9413
# Epoch 58/100, Train Loss: 0.0019, Train Acc: 0.9996, Val Loss: 0.1264, Val Acc: 0.9563
# Epoch 59/100, Train Loss: 0.0188, Train Acc: 0.9954, Val Loss: 0.1030, Val Acc: 0.9600
# Epoch 60/100, Train Loss: 0.0021, Train Acc: 0.9996, Val Loss: 0.1352, Val Acc: 0.9575
# Epoch 61/100, Train Loss: 0.0003, Train Acc: 1.0000, Val Loss: 0.1335, Val Acc: 0.9563
# Epoch 62/100, Train Loss: 0.0209, Train Acc: 0.9946, Val Loss: 0.2050, Val Acc: 0.9263
# Epoch 63/100, Train Loss: 0.0044, Train Acc: 0.9988, Val Loss: 0.4603, Val Acc: 0.8700
# Epoch 64/100, Train Loss: 0.0148, Train Acc: 0.9963, Val Loss: 0.1404, Val Acc: 0.9550
# Epoch 65/100, Train Loss: 0.0016, Train Acc: 1.0000, Val Loss: 0.1513, Val Acc: 0.9463
# Epoch 66/100, Train Loss: 0.0008, Train Acc: 1.0000, Val Loss: 0.1236, Val Acc: 0.9575
# Epoch 67/100, Train Loss: 0.0002, Train Acc: 1.0000, Val Loss: 0.1041, Val Acc: 0.9650
# Epoch 68/100, Train Loss: 0.0001, Train Acc: 1.0000, Val Loss: 0.1326, Val Acc: 0.9550
# Epoch 69/100, Train Loss: 0.0124, Train Acc: 0.9958, Val Loss: 0.6670, Val Acc: 0.8338
# Epoch 70/100, Train Loss: 0.0318, Train Acc: 0.9908, Val Loss: 0.1427, Val Acc: 0.9450
# Epoch 71/100, Train Loss: 0.0014, Train Acc: 1.0000, Val Loss: 0.1693, Val Acc: 0.9400
# Epoch 72/100, Train Loss: 0.0008, Train Acc: 0.9996, Val Loss: 0.1790, Val Acc: 0.9363
# Epoch 73/100, Train Loss: 0.0015, Train Acc: 0.9996, Val Loss: 0.7003, Val Acc: 0.8213
# Epoch 74/100, Train Loss: 0.0326, Train Acc: 0.9892, Val Loss: 0.2128, Val Acc: 0.9250
# Epoch 75/100, Train Loss: 0.0175, Train Acc: 0.9942, Val Loss: 0.2177, Val Acc: 0.9325
# Epoch 76/100, Train Loss: 0.0076, Train Acc: 0.9975, Val Loss: 0.3818, Val Acc: 0.8838
# Epoch 77/100, Train Loss: 0.0033, Train Acc: 0.9988, Val Loss: 0.1653, Val Acc: 0.9413
# Epoch 78/100, Train Loss: 0.0005, Train Acc: 1.0000, Val Loss: 0.1443, Val Acc: 0.9538
# Epoch 79/100, Train Loss: 0.0064, Train Acc: 0.9992, Val Loss: 0.1176, Val Acc: 0.9563
# Epoch 80/100, Train Loss: 0.0007, Train Acc: 1.0000, Val Loss: 0.1007, Val Acc: 0.9613
# Epoch 81/100, Train Loss: 0.0038, Train Acc: 0.9983, Val Loss: 0.6978, Val Acc: 0.8250
# Epoch 82/100, Train Loss: 0.0029, Train Acc: 0.9996, Val Loss: 0.2386, Val Acc: 0.9213
# Epoch 83/100, Train Loss: 0.0012, Train Acc: 0.9996, Val Loss: 0.8222, Val Acc: 0.8138
# Epoch 84/100, Train Loss: 0.0062, Train Acc: 0.9979, Val Loss: 0.2080, Val Acc: 0.9288
# Epoch 85/100, Train Loss: 0.0138, Train Acc: 0.9954, Val Loss: 0.2325, Val Acc: 0.9188
# Epoch 86/100, Train Loss: 0.0148, Train Acc: 0.9958, Val Loss: 0.3742, Val Acc: 0.9075
# Epoch 87/100, Train Loss: 0.0149, Train Acc: 0.9946, Val Loss: 0.1922, Val Acc: 0.9200
# Epoch 88/100, Train Loss: 0.0010, Train Acc: 1.0000, Val Loss: 0.1846, Val Acc: 0.9288
# Epoch 89/100, Train Loss: 0.0002, Train Acc: 1.0000, Val Loss: 0.1896, Val Acc: 0.9313
# Epoch 90/100, Train Loss: 0.0125, Train Acc: 0.9971, Val Loss: 0.2509, Val Acc: 0.9175
# Epoch 91/100, Train Loss: 0.0019, Train Acc: 0.9996, Val Loss: 0.1487, Val Acc: 0.9525
# Epoch 92/100, Train Loss: 0.0002, Train Acc: 1.0000, Val Loss: 0.1689, Val Acc: 0.9438
# Epoch 93/100, Train Loss: 0.0003, Train Acc: 1.0000, Val Loss: 0.1879, Val Acc: 0.9463
# Epoch 94/100, Train Loss: 0.0007, Train Acc: 1.0000, Val Loss: 0.1864, Val Acc: 0.9413
# Epoch 95/100, Train Loss: 0.0003, Train Acc: 1.0000, Val Loss: 0.1197, Val Acc: 0.9625
# Epoch 96/100, Train Loss: 0.0001, Train Acc: 1.0000, Val Loss: 0.1153, Val Acc: 0.9625
# Epoch 97/100, Train Loss: 0.0001, Train Acc: 1.0000, Val Loss: 0.1174, Val Acc: 0.9600
# Epoch 98/100, Train Loss: 0.0001, Train Acc: 1.0000, Val Loss: 0.1120, Val Acc: 0.9613
# Epoch 99/100, Train Loss: 0.0144, Train Acc: 0.9946, Val Loss: 0.4429, Val Acc: 0.8613
# Epoch 100/100, Train Loss: 0.0223, Train Acc: 0.9942, Val Loss: 0.2050, Val Acc: 0.9238

# %% [markdown]
# ## Plotting Acc and Loss Graphics

# %%
# Plotar acurácia
plt.figure(figsize=(10, 5))
plt.plot(range(1, epochs+1), train_accuracies, label='Train Accuracy')
plt.plot(range(1, epochs+1), val_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison')
plt.legend()
plt.grid(True)
output_dir = 'gráficos/Gráficos Resnet50'
os.makedirs(output_dir, exist_ok=True)
plt.savefig(os.path.join(output_dir, f'accuracy_comparison.pdf'))
plt.show()

# %%
# Plotar perda
plt.figure(figsize=(10, 5))
plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, epochs+1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Comparison')
plt.legend()
plt.grid(True)
plt.savefig(os.path.join(output_dir, f'loss_comparison.pdf'))
plt.show()

# %% [markdown]
# ## Testing Best Model

# %%
from torch.utils.data import DataLoader, Subset

transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Entrada padrão para ResNet
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


# Carregar datasets
base_treinamento = datasets.ImageFolder(root='USK-Coffee/train', transform=transformacao)
train_dataloader = DataLoader(base_treinamento, batch_size=10, shuffle=True)

base_validacao = datasets.ImageFolder(root='USK-Coffee/val', transform=transformacao)
validation_dataloader = DataLoader(base_validacao, batch_size=10, shuffle=True)

base_teste = datasets.ImageFolder(root='USK-Coffee/test', transform=transformacao)
test_dataloader = DataLoader(base_teste, batch_size=1, shuffle=False)



model = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1)

# Modificar a camada final para classificação binária
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 1)  # Saída com 1 unidade para classificação binária


# Definir dispositivo
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
print(device)

# Carregar pesos do modelo pré-treinado
checkpoint = torch.load('modelos/pesos_Resnet50/Melhor_modelo_Resnet50.pth')
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()

# Avaliar o modelo
val_loss, val_accuracy = evaluate(model, validation_dataloader, criterion)
print(f"Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.4f}") # conferir se bateu com a melhor acurácia
# Out:
# cuda
# Val Loss: 0.0625, Val Acc: 0.9750

# %%
'''
model.eval()

y_true = []
y_pred = []
y_scores = []

with torch.no_grad():  # desativa a mudança do modelo
    for inputs, labels in validation_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        probs = outputs.squeeze().cpu().numpy()
        predicted = torch.round(outputs).squeeze().cpu().numpy()
        y_true.append(labels.cpu().numpy())
        y_pred.append(predicted.tolist())
        y_scores.append(probs.tolist())
    val_loss, val_accuracy = evaluate(model, validation_dataloader, criterion)
    print(f"Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.4f}")



conf_matrix = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(2)
plt.xticks(tick_marks, ['Premium', 'Defect'], rotation=45)
plt.yticks(tick_marks, ['Premium', 'Defect'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        plt.text(j, i, format(conf_matrix[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if conf_matrix[i, j] > conf_matrix.max() / 2 else "black")
plt.tight_layout()
plt.show()

'''

# %% [markdown]
# # Testing Model

# %%
model.eval()

# Inicialize como arrays vazios
y_true = np.array([])
y_pred = np.array([])
y_scores = np.array([])

with torch.no_grad():
    for inputs, labels in test_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        
        # Aplique Sigmoid para converter logits em probabilidades
        probs = torch.sigmoid(outputs).squeeze().cpu().numpy()
        
        # Converta probabilidades em rótulos binários
        predicted = np.round(probs).astype(int)
        
        # Acumule os valores verdadeiros e previstos
        y_true = np.concatenate((y_true, labels.cpu().numpy().flatten()))
        y_pred = np.concatenate((y_pred, predicted.flatten()))
        y_scores = np.concatenate((y_scores, probs.flatten()))

    test_loss, test_accuracy = evaluate(model, test_dataloader, criterion)
    print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.4f}")
# Out:
# Test Loss: 0.3723, Test Acc: 0.8812

# %% [markdown]
# ## Plotting Confusion Matrix and Precision Recall Graphic

# %%
# Converta listas para arrays NumPy
y_pred = np.array(y_pred)  # Saídas do modelo (logits)
y_true = np.array(y_true)  # Rótulos reais

# Aplique Sigmoid para transformar logits em probabilidades
y_pred = 1 / (1 + np.exp(-y_pred))

# Converta probabilidades para rótulos binários
y_pred = np.round(y_pred).astype(int)  # Binário 0 ou 1
y_true = y_true.astype(int)  # Certifique-se de que y_true seja inteiro

# Calcule a matriz de confusão
conf_matrix = confusion_matrix(y_true, y_pred)

# Visualize a matriz de confusão
plt.figure(figsize=(8, 6))
plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(2)
plt.xticks(tick_marks, ['Premium', 'Defect'], rotation=45)
plt.yticks(tick_marks, ['Premium', 'Defect'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Adicione valores na matriz
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        plt.text(j, i, format(conf_matrix[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if conf_matrix[i, j] > conf_matrix.max() / 2 else "black")

# Ajuste e salve
plt.tight_layout()
output_dir = "results"  # Pasta de saída
os.makedirs(output_dir, exist_ok=True)
plt.savefig(os.path.join(output_dir, 'confusion_matrix.pdf'))
plt.show()

# %%
from sklearn.metrics import precision_recall_curve, f1_score

# precision_recall_curve retorna precisão, recall e os thresholds
precision, recall, _ = precision_recall_curve(y_true, y_scores)

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.grid(True)

# Calcula a pontuação F1
f1 = 2 * (precision * recall) / (precision + recall)

# Encontre o índice do ponto de F1 máximo
idx = np.argmax(f1)

# Extrair o melhor valor de recall no ponto de F1 máximo
best_f1 = f1[idx]
best_recall = recall[idx]

plt.savefig(os.path.join(output_dir, f'Precision-Recall.pdf'))

plt.show()

# Exibe a melhor pontuação F1 e o valor de recall correspondente
print("Melhor pontuação F1:", best_f1)
print("Valor de recall no ponto F1 máximo:", best_recall)
# Out:
# Melhor pontuação F1: 0.8948655256723717
# Valor de recall no ponto F1 máximo: 0.915
